# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Part - 1 : GDP Analysis of the Indian States

# %% [markdown]
# ### Creating the dataframe

# %% [markdown]
# #####  >> Please change the path of the file below before executing the cell

# %%
df_1a_original = pd.read_csv(r'C:\Users\user1\Desktop\AssignmentData\Data1A\ab40c054-5031-4376-b52e-9813e776f65e.csv')

# %%
df_1a_original   # checking the dataframe
# Out:
#                     Items  Description Duration  Andhra Pradesh   \
# 0   GSDP - CURRENT PRICES (` in Crore)  2011-12        379402.00
# 1   GSDP - CURRENT PRICES (` in Crore)  2012-13        411404.00
# 2   GSDP - CURRENT PRICES (` in Crore)  2013-14        464272.00
# 3   GSDP - CURRENT PRICES (` in Crore)  2014-15        526468.00
# 4   GSDP - CURRENT PRICES (` in Crore)  2015-16        609934.00
# 5   GSDP - CURRENT PRICES (` in Crore)  2016-17        699307.00
# 6        (% Growth over previous year)  2012-13             8.43
# 7        (% Growth over previous year)  2013-14            12.85
# 8        (% Growth over previous year)  2014-15            13.40
# 9        (% Growth over previous year)  2015-16            15.85
# 10       (% Growth over previous year)  2016-17            14.65
#
#     Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa  \
# 0            11063.00  143175.00  247144.00     158074.00  42367.00
# ...

# %%
df_1a_original.shape # checking the shape of dataframe
# Out:
# (11, 36)

# %% [markdown]
# ## Part 1 A -  1 -  Remove the rows: '(% Growth over the previous year)' and 'GSDP - CURRENT PRICES (' in Crore)' for the year 2016-17.

# %%
df_1a_1=df_1a_original.loc[df_1a_original.Duration!='2016-17']   # removing the rows using != operator

# %%
df_1a_1  # checking the dataframe after removal of rows for 2016-17
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 0  GSDP - CURRENT PRICES (` in Crore)  2011-12        379402.00
# 1  GSDP - CURRENT PRICES (` in Crore)  2012-13        411404.00
# 2  GSDP - CURRENT PRICES (` in Crore)  2013-14        464272.00
# 3  GSDP - CURRENT PRICES (` in Crore)  2014-15        526468.00
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16        609934.00
# 6       (% Growth over previous year)  2012-13             8.43
# 7       (% Growth over previous year)  2013-14            12.85
# 8       (% Growth over previous year)  2014-15            13.40
# 9       (% Growth over previous year)  2015-16            15.85
#
#    Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa    Gujarat  \
# 0           11063.00  143175.00  247144.00     158074.00  42367.00  615606.00
# 1           12547.00  156864.00  282368.00     177511.00  38120.00  724495.00
# 2           14602.00  177745.00  317101.00     206690.00  35921.00  807623.00
# ...

# %%
df_1a_1.shape # To check new size after rows deleted
# Out:
# (9, 36)

# %% [markdown]
# ## Part 1 A  - 2 -  Calculate the average growth of states for the duration 2013-14, 2014-15 and 2015-16 by taking the mean of the row '(% Growth over previous year)'. Compare the calculated values and plot them for the states.

# %% [markdown]
# #### Creating a new dataframe for % Growth over previous year and required years = 2013-14 , 2014-15, 2015-16

# %%
df_1a_2 = df_1a_1[(df_1a_1['Items  Description'] == '(% Growth over previous year)') & ((df_1a_1['Duration']=='2013-14') | (df_1a_1['Duration']=='2014-15') | (df_1a_1['Duration']=='2015-16'))]
df_1a_2
# Out:
#               Items  Description Duration  Andhra Pradesh   Arunachal Pradesh  \
# 7  (% Growth over previous year)  2013-14            12.85              16.38
# 8  (% Growth over previous year)  2014-15            13.40              14.79
# 9  (% Growth over previous year)  2015-16            15.85              12.07
#
#    Assam  Bihar  Chhattisgarh    Goa  Gujarat  Haryana  Himachal Pradesh  \
# 7  13.31  12.30         16.44  -5.77    11.47    15.45             14.42
# 8  11.45  17.92         13.69  13.12    10.82     9.18             10.14
# 9  13.19  10.59         10.98  10.75    11.09    10.91               NaN
#
#    Jammu & Kashmir  Jharkhand  Karnataka  Kerala  Madhya Pradesh  Maharashtra  \
# 7            10.09       7.92      18.24   12.79           14.91        13.74
# 8             4.70      15.14      12.70   13.11           10.11         8.78
# 9            17.91      11.44      11.42   11.85           12.86          NaN
#
# ...

# %% [markdown]
# ### Dropping the not required column = All_India GDP  , taking the mean , sorting the values in descending order and  plotting the graph
# ### I am not doing anything with NaN values as imputing the value for NaN can mislead the data so I am taking the mean of all values including NaN and NaN will be auto handled by the Python

# %%
df_1a_2 = df_1a_2.drop(columns=['All_India GDP'])  # dropping 'All_India GDP' column from the dataframe

# %%
df_1a_2.mean().sort_values(ascending=False).plot(title = 'Average growth of states for the duration 2013-14, 2014-15 and 2015-16', kind='bar', figsize = (12,8))
plt.show()

# %% [markdown]
# ## Mizoram is the state which has significant growth from Year to Year and Goa is the state which is not showing the growth from Year to Year.

# %% [markdown]
# ## Part 1 A  - 3 -   Average growth rate of your home state, and how does it compare to the national average over this duration

# %% [markdown]
# ### Creating a new dataframe with the required columns with home state and All India

# %%
df_1a_3 = df_1a_1[['Items  Description','Duration', 'Delhi','All_India GDP']]
df_1a_3
# Out:
#                    Items  Description Duration      Delhi  All_India GDP
# 0  GSDP - CURRENT PRICES (` in Crore)  2011-12  343767.00     8736039.00
# 1  GSDP - CURRENT PRICES (` in Crore)  2012-13  391238.00     9946636.00
# 2  GSDP - CURRENT PRICES (` in Crore)  2013-14  443783.00    11236635.00
# 3  GSDP - CURRENT PRICES (` in Crore)  2014-15  492424.00    12433749.00
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16  551963.00    13675331.00
# 6       (% Growth over previous year)  2012-13      13.81          13.86
# 7       (% Growth over previous year)  2013-14      13.43          12.97
# 8       (% Growth over previous year)  2014-15      10.96          10.65
# 9       (% Growth over previous year)  2015-16      12.09           9.99

# %% [markdown]
# ### Updating the data for the required column value and duration

# %%
df_1a_3 = df_1a_3[(df_1a_3['Items  Description'] == '(% Growth over previous year)') & ((df_1a_3['Duration']=='2013-14') | (df_1a_3['Duration']=='2014-15') | (df_1a_3['Duration']=='2015-16'))]
df_1a_3
# Out:
#               Items  Description Duration  Delhi  All_India GDP
# 7  (% Growth over previous year)  2013-14  13.43          12.97
# 8  (% Growth over previous year)  2014-15  10.96          10.65
# 9  (% Growth over previous year)  2015-16  12.09           9.99

# %% [markdown]
# ###  Taking the mean , sorting the values in descending order and plotting the graph

# %%
df_1a_3.mean().sort_values(ascending=False).plot(title = 'Average growth rate of home state as compared to the National average over this duration', kind='bar', figsize = (12,8))
plt.show()

# %% [markdown]
# ## Delhi is showing significant growth as similar to All India growth from year to year

# %% [markdown]
# ## Part 1 A - 4 -  Plot the total GDP of the states for the year 2015-16

# %% [markdown]
# ### Creating a new dataframe with required row values

# %%
df_1a_4 = df_1a_1[(df_1a_1['Items  Description'] == 'GSDP - CURRENT PRICES (` in Crore)') & (df_1a_1['Duration'] == '2015-16')]
df_1a_4  # zfter creating the df , checking it
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16         609934.0
#
#    Arunachal Pradesh     Assam     Bihar  Chhattisgarh      Goa   Gujarat  \
# 4            18784.0  224234.0  413503.0      260776.0  45002.0  994316.0
#
#     Haryana  Himachal Pradesh  Jammu & Kashmir  Jharkhand  Karnataka  \
# 4  485184.0               NaN         118387.0   241955.0  1027068.0
#
#      Kerala  Madhya Pradesh  Maharashtra  Manipur  Meghalaya  Mizoram  \
# 4  588337.0        543975.0          NaN      NaN    26745.0      NaN
#
#    Nagaland    Odisha  Punjab  Rajasthan   Sikkim  Tamil Nadu  Telangana  \
# 4       NaN  341887.0     NaN        NaN  16637.0   1212668.0   575631.0
#
#    Tripura  Uttar Pradesh  Uttarakhand  West Bengal1  \
# 4      NaN      1153795.0     184091.0           NaN
#
#    Andaman & Nicobar Islands  Chandigarh     Delhi  Puducherry  All_India GDP
# ...

# %%
df_1a_4 = df_1a_4.drop(columns = ['Duration','Andaman & Nicobar Islands', 'Chandigarh', 'Delhi', 'Puducherry', 'All_India GDP'])
# dropping the not required columns

# %%
df_1a_4=df_1a_4.T  # transposing the dataframe
df_1a_4  # checking the dataframe after transposing it
# Out:
#                                                      4
# Items  Description  GSDP - CURRENT PRICES (` in Crore)
# Andhra Pradesh                                  609934
# Arunachal Pradesh                                18784
# Assam                                           224234
# Bihar                                           413503
# Chhattisgarh                                    260776
# Goa                                              45002
# Gujarat                                         994316
# Haryana                                         485184
# Himachal Pradesh                                   NaN
# Jammu & Kashmir                                 118387
# Jharkhand                                       241955
# Karnataka                                  1.02707e+06
# Kerala                                          588337
# Madhya Pradesh                                  543975
# Maharashtra                                        NaN
# ...

# %%
df_1a_4.shape  # checking the shape of dataframe after transposing it above
# Out:
# (30, 1)

# %%
df_1a_4.columns = df_1a_4.iloc[0]    # updating the column headers to first row
df_1a_4
# Out:
# Items  Description  GSDP - CURRENT PRICES (` in Crore)
# Items  Description  GSDP - CURRENT PRICES (` in Crore)
# Andhra Pradesh                                  609934
# Arunachal Pradesh                                18784
# Assam                                           224234
# Bihar                                           413503
# Chhattisgarh                                    260776
# Goa                                              45002
# Gujarat                                         994316
# Haryana                                         485184
# Himachal Pradesh                                   NaN
# Jammu & Kashmir                                 118387
# Jharkhand                                       241955
# Karnataka                                  1.02707e+06
# Kerala                                          588337
# Madhya Pradesh                                  543975
# Maharashtra                                        NaN
# ...

# %%
df_1a_4 = df_1a_4[1:]   # updating the dataframe and removing the first row which was updated as column header
df_1a_4
# Out:
# Items  Description GSDP - CURRENT PRICES (` in Crore)
# Andhra Pradesh                                 609934
# Arunachal Pradesh                               18784
# Assam                                          224234
# Bihar                                          413503
# Chhattisgarh                                   260776
# Goa                                             45002
# Gujarat                                        994316
# Haryana                                        485184
# Himachal Pradesh                                  NaN
# Jammu & Kashmir                                118387
# Jharkhand                                      241955
# Karnataka                                 1.02707e+06
# Kerala                                         588337
# Madhya Pradesh                                 543975
# Maharashtra                                       NaN
# Manipur                                           NaN
# ...

# %%
df_1a_4 = df_1a_4.sort_values(by = ['GSDP - CURRENT PRICES (` in Crore)'], ascending = False)  # sorting the values in dataframe
df_1a_4
# Out:
# Items  Description GSDP - CURRENT PRICES (` in Crore)
# Tamil Nadu                                1.21267e+06
# Uttar Pradesh                              1.1538e+06
# Karnataka                                 1.02707e+06
# Gujarat                                        994316
# Andhra Pradesh                                 609934
# Kerala                                         588337
# Telangana                                      575631
# Madhya Pradesh                                 543975
# Haryana                                        485184
# Bihar                                          413503
# Odisha                                         341887
# Chhattisgarh                                   260776
# Jharkhand                                      241955
# Assam                                          224234
# Uttarakhand                                    184091
# Jammu & Kashmir                                118387
# ...

# %% [markdown]
# ### I am not doing anything with NaN values as imputing the value for NaN can mislead the data so I am taking the mean of all values including NaN and NaN will be auto handled by the Python

# %%
df_1a_4.head(5)  # checking the top 5 of the dataframe
df_1a_4.plot(title = 'Total GDP of the states for the year 2015-16', kind='bar', figsize = (12,8))
plt.show()

# %% [markdown]
# ## Tamil Nadu has highest GDP and Sikkim has lowest GDP
# ## 5 States with High GDP -  Tamil Nadu, Uttar Pradesh, Karnataka, Gujarat, Andhra Pradesh
# ## 5 States with Low GDP -  Sikkim, Arunachal Pradesh, Meghalaya, Goa, Jammu & Kashmir

# %% [markdown]
# ## Part 1 B -  Perform the analysis only for the duration 2014-15

# %%
import glob  # Pattern matching library that will fetch all the files having same type of extension

# %% [markdown]
# #####  >> Please change the path of the file below before executing the cell

# %%
path = r'C:\Users\user1\Desktop\AssignmentData\Data1B'

# %%
all_files = glob.glob(path+"\\*csv")

# %%
#new_header = df.iloc[0]
all_files[0].split('\\')[-1].split('-')[1]  # for checking the statename based on extracting it from file name
# Out:
# 'Andhra_Pradesh'

# %% [markdown]
# ### Part 1 B - 1 - Creating dataframe by reading the files and extracting the value for new column - State and for 2014-15 only

# %%
li = []

for filename in all_files:
    df = pd.read_csv(filename,encoding='unicode_escape',index_col=None,header=0)
    df = df[['Item','2014-15']]
    df = df.T
    new_header = df.iloc[0]
    df.columns = new_header.str.replace('*','')
    df.columns = df.columns.str.strip()
    df = df[1:]
    df.loc[:,'State']=filename.split('\\')[-1].split('-')[1]
    li.append(df)

# %%
li
# Out:
# [Item    Agriculture, forestry and fishing    Crops Livestock  \
#  2014-15                          14819416  7893514   4309078
#
#  Item    Forestry and logging Fishing and aquaculture Mining and quarrying  \
#  2014-15               346160                 2270664              1484300
#
#  Item      Primary Manufacturing  \
#  2014-15  16303716       4672266
#
#  Item    Electricity, gas, water supply & other utility services Construction  \
#  2014-15                                            1151729           4664889
#
#  Item     ... Public administration Other services  Tertiary  \
#  2014-15  ...               2200897        4215389  22032942
#
#  Item    TOTAL GSVA at basic prices Taxes on Products Subsidies on products  \
#  2014-15                   48825542           5512100               1690800
#
#  Item    Gross State Domestic Product Population ('00) Per Capita GSDP (Rs.)  \
#  2014-15                     52646842           501510                104977
#
# ...

# %%
pd.set_option('display.max_columns', 500)
df = pd.concat(li,axis=0,ignore_index = True,sort=True) # Concatenation of values and assigning it to dataframe
df
# Out:
# Item Agriculture, forestry and fishing Air transport  \
# 0                             14819416         14900
# 1                               686117             0
# 2                              3855548         26223
# 3                              7951890         13599
# 4                                16233         12391
# 5                              3948847          9507
# 6                               250568        420460
# 7                               308507         46359
# 8                            1.377e+07           NaN
# 9                          8.01524e+06           NaN
# 10                             1514981          3979
# 11                             3211065          6716
# 12                            11219422        171785
# 13                             5930617        125029
# 14                            16235647         26746
# 15                            16475655        174188
# 16                              383140          6288
# ...

# %%
df.columns  # for checking the colummns
# Out:
# Index(['Agriculture, forestry and fishing', 'Air transport',
#        'Communication & services related to broadcasting', 'Construction',
#        'Crops', 'Electricity, gas, water supply & other utility services',
#        'Financial services', 'Fishing and aquaculture', 'Forestry and logging',
#        'Gross State Domestic Product', 'Hotels & restaurants', 'Livestock',
#        'Manufacturing', 'Mining and quarrying', 'Other services',
#        'Per Capita GSDP (Rs.)', 'Population ('00)', 'Primary',
#        'Public administration', 'Railways',
#        'Real estate, ownership of dwelling & professional services',
#        'Road transport', 'Secondary', 'Services incidental to transport',
#        'State', 'Storage', 'Subsidies on products',
#        'TOTAL GSVA at basic prices', 'Taxes on Products', 'Tertiary',
#        'Trade & repair services', 'Trade, repair, hotels and restaurants',
#        'Transport, storage, communication & services related to broadcasting',
# ...

# %%
df.shape  #  checking the size of dataframe
# Out:
# (30, 34)

# %% [markdown]
# ### Part 1 B - 2 - Filter out the union territories (Delhi, Chandigarh, Andaman and Nicobar Islands, etc.)

# %%
# Removing rows where state value = Union Territories
df = df.loc[(df.State != 'Andaman & Nicobar Islands') & (df.State != 'Chandigarh') & (df.State != 'Delhi') & (df.State != 'Puducherry')]

# %%
df.shape # size after removing the rows
# Out:
# (27, 34)

# %% [markdown]
# ### Creating new dataframe for Part 1B - 2

# %%
# creating the dataframe with required columns only from main dataframe and sorting the values
df_1b2 = df[['State','Per Capita GSDP (Rs.)']].sort_values(by = ['Per Capita GSDP (Rs.)'], ascending = False)

# %%
df_1b2.shape # checking the size of the frame after creating it
# Out:
# (27, 2)

# %%
df_1b2 # checking the data sorted in descending order of Per Capita GDP
# Out:
# Item              State Per Capita GSDP (Rs.)
# 7                   Goa                271793
# 24               Sikkim                240274
# 9               Haryana                164077
# 13               Kerala                154778
# 28          Uttarakhand                153076
# 15          Maharashtra                152853
# 10     Himachal_Pradesh                147330
# 25           Tamil_Nadu                146503
# 12            Karnataka                145141
# 8               Gujarat                141263
# 26            Telangana                139035
# 22               Punjab                126606
# 1     Arunachal_Pradesh                112718
# 0        Andhra_Pradesh                104977
# 18              Mizoram                 97687
# 19             Nagaland                 89607
# 5          Chhattisgarh                 86860
# 23            Rajasthan                 84837
# 27              Tripura                 77358
# ...

# %%
# plotting the graph
df_1b2.plot(title = 'Per Capita GSDP for all States for 2014-15', x='State' , y='Per Capita GSDP (Rs.)', kind='bar', figsize = (12,8))   
plt.show()

# %% [markdown]
# ## Goa has highest percapitaGDP and Bihar has lowest percapitaGDP

# %% [markdown]
# ###  Ratio of the highest per capita GDP to the lowest per capita GDP

# %%
Ratio_High_Low = df_1b2['Per Capita GSDP (Rs.)'].max()/df_1b2['Per Capita GSDP (Rs.)'].min()
Ratio_High_Low
# Out:
# 8.004741709371503

# %% [markdown]
# ## Part 1 B - 3 -  Percentage contribution of the primary, secondary and tertiary sectors as a percentage of the total GDP for all the states

# %% [markdown]
# ###  Creating the dataframe with the required columns from the main dataframe

# %%
df_1b3= df[['State','Primary','Secondary','Tertiary','Gross State Domestic Product']]

# %%
df_1b3.shape
# Out:
# (27, 5)

# %%
# Creating new columns with value of percentage of sectors of total GSDP
df_1b3 = df_1b3.copy()
df_1b3['primary_contribution'] = (df_1b3['Primary']/df_1b3['Gross State Domestic Product'])*100 
df_1b3['secondary_contribution'] = (df_1b3['Secondary']/df_1b3['Gross State Domestic Product'])*100
df_1b3['tertiary_contribution'] = (df_1b3['Tertiary']/df_1b3['Gross State Domestic Product'])*100

# %%
df_1b3.shape
# Out:
# (27, 8)

# %%
df_1b3 = df_1b3.sort_values(by = ['Gross State Domestic Product'], ascending = False)  # sorting the values of dataframe

# %%
df_1b3
# Out:
# Item              State      Primary    Secondary     Tertiary  \
# 15          Maharashtra     21758383     47445207     88631076
# 25           Tamil_Nadu     13329774     32841892     53343788
# 29        Uttar_Pradesh     25999255     25548724     45968959
# 12            Karnataka     12066304     20484404     50490630
# 8               Gujarat  1.58872e+07  3.30235e+07  3.02204e+07
# 23            Rajasthan     19113780     13028794     26015812
# 0        Andhra_Pradesh     16303716     10488884     22032942
# 13               Kerala      6489442     12070040     29673778
# 26            Telangana      9133354      9924001     28471410
# 14       Madhya_Pradesh     17854020     10044889     18117360
# 9               Haryana  8.04042e+06  1.25614e+07  1.92266e+07
# 3                 Bihar      8019997      5984896     22179969
# 22               Punjab      9296070      7904914     16717805
# 20               Odisha      9009306      8989693     12256258
# ...

# %%
# redefining the dataframe with required columns only
df_1b3 = df_1b3[['State','primary_contribution','secondary_contribution','tertiary_contribution']]

# %%
df_1b3
# Out:
# Item              State primary_contribution secondary_contribution  \
# 15          Maharashtra              12.1411                26.4743
# 25           Tamil_Nadu              12.2005                30.0595
# 29        Uttar_Pradesh              24.9185                24.4867
# 12            Karnataka              13.0901                22.2225
# 8               Gujarat              17.7505                36.8967
# 23            Rajasthan              31.2217                21.2821
# 0        Andhra_Pradesh              30.9681                19.9231
# 13               Kerala              12.3373                22.9467
# 26            Telangana              17.8673                 19.414
# 14       Madhya_Pradesh              37.0429                20.8408
# 9               Haryana              18.3797                28.7143
# 3                 Bihar              21.4484                16.0058
# 22               Punjab              25.2603                21.4801
# ...

# %%
# plotting the graph
df_1b3.plot(title = 'Percentage contribution of the primary, secondary and tertiary sectors as a percentage of the total GDP for all the states for 2014-15', x='State',stacked=True, kind = 'bar', figsize=(12,8))
plt.show()

# %% [markdown]
# ## The tertiary sector contribution to the total GDP is high among the states

# %%
df.describe()  # describing the main dataframe
# Out:
# Item    Agriculture, forestry and fishing  Air transport  \
# count                                27.0           24.0
# unique                               27.0           23.0
# top                            16235647.0            0.0
# freq                                  1.0            2.0
#
# Item    Communication & services related to broadcasting  Construction  \
# count                                               27.0          27.0
# unique                                              27.0          27.0
# top                                              19568.0      165819.0
# freq                                                 1.0           1.0
#
# Item       Crops  Electricity, gas, water supply & other utility services  \
# count       27.0                                               27.0
# unique      27.0                                               27.0
# top     853758.0                                          3409983.0
# ...

# %% [markdown]
# ## Part 1B - 4 - Categorise the states into four groups based on the GDP per capita (C1, C2, C3, C4, where C1 would have the highest per capita GDP and C4, the lowest). The quantile values are (0.20,0.5, 0.85, 1), i.e., the states lying between the 85th and the 100th percentile are in C1; those between the 50th and the 85th percentiles are in C2, and so on

# %% [markdown]
# ###  Categorisation into four groups will simplify the subsequent analysis, as otherwise, comparing the data of all the states would become quite exhaustive.

# %% [markdown]
# ### Creating the dataframe for this part

# %%
df_1b4 = df[:]

# %% [markdown]
# ### Calculating the quantile values

# %%
quantile_val = list(df_1b4['Per Capita GSDP (Rs.)'].quantile([0.20,0.50,0.85,1.00]))
quantile_val
# Out:
# [65187.0, 104977.0, 153246.19999999998, 271793.0]

# %% [markdown]
# ### Rounding off the quantile values

# %%
quantile_val = [round(x) for x in quantile_val]

# %%
quantile_val
# Out:
# [65187, 104977, 153246, 271793]

# %%
quantile_val[0]
# Out:
# 65187

# %% [markdown]
# ### Categorizing the States based on quantile value and assigning those values into new column

# %%
df_1b4 = df_1b4.copy()
categorylist = []

for i in df_1b4['Per Capita GSDP (Rs.)']:
    if i <= quantile_val[0]:
        categorylist.append('C4')
    elif (i > quantile_val[0] and i <= quantile_val[1]):
        categorylist.append('C3')
    elif (i > quantile_val[1] and i <= quantile_val[2]):
        categorylist.append('C2')
    elif (i > quantile_val[2] and i <= quantile_val[3]):
        categorylist.append('C1')
    else:
         categorylist.append('Other')
df_1b4['Category']=categorylist

# %%
df_1b4[df_1b4.Category=='C1']  # checking the values for C1 category
# Out:
# Item Agriculture, forestry and fishing Air transport  \
# 7                               308507         46359
# 9                          8.01524e+06           NaN
# 13                             5930617        125029
# 24                              137447             0
#
# Item Communication & services related to broadcasting Construction  \
# 7                                               44028       165819
# 9                                              479658  3.70257e+06
# 13                                             884767      7314003
# 24                                              12064        82058
#
# Item        Crops Electricity, gas, water supply & other utility services  \
# 7          140421                                             204110
# 9     4.63673e+06                                        1.10192e+06
# 13        3070386                                             482470
# 24         114976                                             212499
#
# ...

# %%
df_1b4.shape
# Out:
# (27, 35)

# %% [markdown]
# ### Creating the new dataframe C1 for C1 category only

# %%
df_c1 =  df_1b4[df_1b4.Category=='C1']

# %%
df_c1.shape
# Out:
# (4, 35)

# %%
df_c1
# Out:
# Item Agriculture, forestry and fishing Air transport  \
# 7                               308507         46359
# 9                          8.01524e+06           NaN
# 13                             5930617        125029
# 24                              137447             0
#
# Item Communication & services related to broadcasting Construction  \
# 7                                               44028       165819
# 9                                              479658  3.70257e+06
# 13                                             884767      7314003
# 24                                              12064        82058
#
# Item        Crops Electricity, gas, water supply & other utility services  \
# 7          140421                                             204110
# 9     4.63673e+06                                        1.10192e+06
# 13        3070386                                             482470
# 24         114976                                             212499
#
# ...

# %%
df_c1['Gross State Domestic Product'].sum() # checking the sum value of GSDP
# Out:
# 101930677.0

# %% [markdown]
# ### Creating new dataframe for storing the percentage values

# %%
df_c1_percent = (df_c1[['Agriculture, forestry and fishing', 'Construction', 'Electricity, gas, water supply & other utility services', 'Financial services', 'Manufacturing', 'Mining and quarrying', 'Other services', 'Public administration', 'Real estate, ownership of dwelling & professional services', 'Trade, repair, hotels and restaurants', 'Transport, storage, communication & services related to broadcasting']].sum()/df_c1['Gross State Domestic Product'].sum())*100

# %%
df_c1_percent = df_c1_percent.to_frame()  # converting from series to dataframe

# %%
df_c1_percent.shape
# Out:
# (11, 1)

# %%
df_c1_percent.columns = ['C1%age']  #assigning column name

# %%
# sorting the values according to %age in descending order
df_c1_percent=df_c1_percent.sort_values(by='C1%age',ascending = False)

# %%
df_c1_percent  # dataframe after sorting the values in descending order
# Out:
#                                                        C1%age
# Item
# Real estate, ownership of dwelling & profession...  14.461049
# Agriculture, forestry and fishing                   14.119213
# Trade, repair, hotels and restaurants               13.730076
# Manufacturing                                       13.498187
# Construction                                        11.051090
# Other services                                       7.907258
# Transport, storage, communication & services re...   6.689409
# Financial services                                   3.861928
# Public administration                                3.503648
# Electricity, gas, water supply & other utility ...   1.963097
# Mining and quarrying                                 0.577805

# %%
df_c1_percent['C1%age'].sum() # to ensure that we are getting sum around 80 or more than 80 to identify the sub sectors
# Out:
# 91.36275922115186

# %% [markdown]
# ### Creating new column for cumulative sum and doing the calculation for populating its values

# %%
df_c1_percent['cum_%sum'] = df_c1_percent['C1%age'].cumsum()

# %% [markdown]
# ###  Dataframe with cumulative sum percentage

# %%
df_c1_percent
# Out:
#                                                        C1%age   cum_%sum
# Item
# Real estate, ownership of dwelling & profession...  14.461049  14.461049
# Agriculture, forestry and fishing                   14.119213  28.580261
# Trade, repair, hotels and restaurants               13.730076  42.310337
# Manufacturing                                       13.498187  55.808524
# Construction                                        11.051090  66.859614
# Other services                                       7.907258  74.766872
# Transport, storage, communication & services re...   6.689409  81.456281
# Financial services                                   3.861928  85.318209
# Public administration                                3.503648  88.821857
# Electricity, gas, water supply & other utility ...   1.963097  90.784954
# Mining and quarrying                                 0.577805  91.362759

# %% [markdown]
# ### Updating the dataframe with cumulative sum upto 80 only

# %%
df_c1_percent = df_c1_percent[df_c1_percent['cum_%sum'] <= 80]

# %% [markdown]
# ### Plotting the graph for C1

# %%
df_c1_percent.plot(title = 'C1 top 3/4/5 sub-sectors that contribute to approximately 80% of the GSDP', y='C1%age', kind='bar',figsize = (10,6))
plt.show()

# %% [markdown]
# ## In C1 - Real estate most contributing sub-sector to 80% of GSDP followed by Agriculture, Trade, Manufacturing and Construction

# %% [markdown]
# ### Performing the same steps for C2 which were performed for C1 and plotting the graph for C2

# %%
df_c2 =  df_1b4[df_1b4.Category=='C2']
df_c2.shape
df_c2
df_c2['Gross State Domestic Product'].sum()
df_c2_percent = (df_c2[['Agriculture, forestry and fishing', 'Construction', 'Electricity, gas, water supply & other utility services', 'Financial services', 'Manufacturing', 'Mining and quarrying', 'Other services', 'Public administration', 'Real estate, ownership of dwelling & professional services', 'Trade, repair, hotels and restaurants', 'Transport, storage, communication & services related to broadcasting']].sum()/df_c2['Gross State Domestic Product'].sum())*100
df_c2_percent = df_c2_percent.to_frame()
df_c2_percent.dtypes
df_c2_percent.shape
df_c2_percent.columns = ['C2%age']
df_c2_percent=df_c2_percent.sort_values(by='C2%age',ascending = False)
df_c2_percent
df_c2_percent['C2%age'].sum()
df_c2_percent['cum_%sum'] = df_c2_percent['C2%age'].cumsum()
df_c2_percent
df_c2_percent = df_c2_percent[df_c2_percent['cum_%sum'] <= 80]
df_c2_percent.plot(title = 'C2 top 3/4/5 sub-sectors that contribute to approximately 80% of the GSDP', y='C2%age', kind='bar',figsize = (10,6))
plt.show()

# %% [markdown]
# ## In C2 - Manufacturing most contributing sub-sector to 80% of GSDP followed by Real estate , Agriculture, Trade,  and Construction

# %% [markdown]
# ### Performing the same steps for C3 which were performed for C2 and plotting the graph for C3

# %%
df_c3 =  df_1b4[df_1b4.Category=='C3']
df_c3.shape
df_c3
df_c3['Gross State Domestic Product'].sum()
df_c3_percent = (df_c3[['Agriculture, forestry and fishing', 'Construction', 'Electricity, gas, water supply & other utility services', 'Financial services', 'Manufacturing', 'Mining and quarrying', 'Other services', 'Public administration', 'Real estate, ownership of dwelling & professional services', 'Trade, repair, hotels and restaurants', 'Transport, storage, communication & services related to broadcasting']].sum()/df_c3['Gross State Domestic Product'].sum())*100
df_c3_percent = df_c3_percent.to_frame()
df_c3_percent.dtypes
df_c3_percent.shape
df_c3_percent.columns = ['C3%age']
df_c3_percent=df_c3_percent.sort_values(by='C3%age',ascending = False)
df_c3_percent
df_c3_percent['C3%age'].sum()
df_c3_percent['cum_%sum'] = df_c3_percent['C3%age'].cumsum()
df_c3_percent
df_c3_percent = df_c3_percent[df_c3_percent['cum_%sum'] <= 80]
df_c3_percent.plot(title = 'C3 top 3/4/5 sub-sectors that contribute to approximately 80% of the GSDP', y='C3%age', kind='bar',figsize = (10,6))
plt.show()

# %% [markdown]
# ## In C3 -  Agriculture most contributing sub-sector to 80% of GSDP followed by Manufacturing, Trade, Real estate  and Construction

# %% [markdown]
# ### Performing the same steps for C4 which were performed for C3 and plotting the graph for C4

# %%
df_c4 =  df_1b4[df_1b4.Category=='C4']
df_c4.shape
df_c4
df_c4['Gross State Domestic Product'].sum()
df_c4_percent = (df_c4[['Agriculture, forestry and fishing', 'Construction', 'Electricity, gas, water supply & other utility services', 'Financial services', 'Manufacturing', 'Mining and quarrying', 'Other services', 'Public administration', 'Real estate, ownership of dwelling & professional services', 'Trade, repair, hotels and restaurants', 'Transport, storage, communication & services related to broadcasting']].sum()/df_c4['Gross State Domestic Product'].sum())*100
df_c4_percent = df_c4_percent.to_frame()
df_c4_percent.dtypes
df_c4_percent.shape
df_c4_percent.columns = ['C4%age']
df_c4_percent=df_c4_percent.sort_values(by='C4%age',ascending = False)
df_c4_percent
df_c4_percent['C4%age'].sum()
df_c4_percent['cum_%sum'] = df_c4_percent['C4%age'].cumsum()
df_c4_percent
df_c4_percent = df_c4_percent[df_c4_percent['cum_%sum'] <= 80]
df_c4_percent.plot(title = 'C4 top 3/4/5 sub-sectors that contribute to approximately 80% of the GSDP', y='C4%age', kind='bar',figsize = (10,6))
plt.show()

# %% [markdown]
# ## In C4 -  Agriculture most contributing sub-sector to 80% of GSDP followed by  Trade, Manufacturing, Real estate  and Construction

# %% [markdown]
# # Part 2 - GDP and Education Dropout Rates

# %% [markdown]
# ### Creating the first dataframe with State and PerCapitaGDP

# %%
df_2a = df[['State','Per Capita GSDP (Rs.)']].sort_values(by = ['Per Capita GSDP (Rs.)'], ascending = False)

# %%
df_2a.shape
# Out:
# (27, 2)

# %% [markdown]
# #####  >> Please change the path before executing the cell

# %% [markdown]
# ### Creating the 2nd dataframe from the file regarding Dropout

# %%
df_2b = pd.read_csv(r'C:\Users\user1\Desktop\AssignmentData\Data2\rs_session243_au570_1.1.csv')

# %%
df_2b.shape
# Out:
# (37, 14)

# %%
df_2b.columns
# Out:
# Index(['Sl. No.', 'Level of Education - State', 'Primary - 2012-2013',
#        'Primary - 2014-2015', 'Primary - 2014-2015.1',
#        'Upper Primary - 2012-2013', 'Upper Primary - 2013-2014',
#        'Upper Primary - 2014-2015', 'Secondary - 2012-2013',
#        'Secondary - 2013-2014', 'Secondary - 2014-2015',
#        'Senior Secondary - 2012-2013', 'Senior Secondary - 2013-2014',
#        'Senior Secondary - 2014-2015'],
#       dtype='object')

# %%
df_2b = df_2b[['Level of Education - State','Primary - 2014-2015.1','Upper Primary - 2014-2015','Secondary - 2014-2015','Senior Secondary - 2014-2015']]

# %%
df_2b
# Out:
#    Level of Education - State  Primary - 2014-2015.1  \
# 0               A & N Islands                   0.51
# 1              Andhra Pradesh                   6.72
# 2           Arunachal Pradesh                  10.82
# 3                       Assam                  15.36
# 4                       Bihar                    NaN
# 5                  Chandigarh                    NaN
# 6                 Chhatisgarh                   2.91
# 7        Dadra & Nagar Haveli                   1.47
# 8                 Daman & Diu                   1.11
# 9                       Delhi                    NaN
# 10                        Goa                   0.73
# 11                    Gujarat                   0.89
# 12                    Haryana                   5.61
# 13           Himachal Pradesh                   0.64
# 14          Jammu and Kashmir                   6.79
# 15                  Jharkhand                   5.48
# 16                  Karnataka                   2.02
# ...

# %%
df_2a.State.count()
# Out:
# 27

# %% [markdown]
# ### Renaming the columns of GDP Per Capita dataframe to match with dropout dataframe

# %%
df_2a['State'] = df_2a['State'].apply(lambda x: x.replace('_', ' '))
df_2a['State'] = df_2a['State'].apply(lambda x: x.replace('Chhattisgarh', 'Chhatisgarh'))
df_2a['State'] = df_2a['State'].apply(lambda x: x.replace('Uttarakhand', 'Uttrakhand'))

# %%
df_2b = df_2b.loc[(df_2b['Level of Education - State'] != 'A & N Islands') & (df_2b['Level of Education - State'] != 'Chandigarh') & (df_2b['Level of Education - State'] != 'Dadra & Nagar Haveli') & (df_2b['Level of Education - State'] != 'Daman & Diu') & (df_2b['Level of Education - State'] != 'Delhi') & (df_2b['Level of Education - State'] != 'Lakshadweep') & (df_2b['Level of Education - State'] != 'Puducherry') & (df_2b['Level of Education - State'] != 'All India')]
df_2b = df_2b.rename(columns = {'Level of Education - State':'State'})

# %%
df_2a.State
# Out:
# 7                   Goa
# 24               Sikkim
# 9               Haryana
# 13               Kerala
# 28           Uttrakhand
# 15          Maharashtra
# 10     Himachal Pradesh
# 25           Tamil Nadu
# 12            Karnataka
# 8               Gujarat
# 26            Telangana
# 22               Punjab
# 1     Arunachal Pradesh
# 0        Andhra Pradesh
# 18              Mizoram
# 19             Nagaland
# 5           Chhatisgarh
# 23            Rajasthan
# 27              Tripura
# 17            Meghalaya
# 20               Odisha
# 14       Madhya Pradesh
# 11            Jharkhand
# 2                 Assam
# 16              Manipur
# 29        Uttar Pradesh
# 3                 Bihar
# Name: State, dtype: object

# %%
df_2b.columns
# Out:
# Index(['State', 'Primary - 2014-2015.1', 'Upper Primary - 2014-2015',
#        'Secondary - 2014-2015', 'Senior Secondary - 2014-2015'],
#       dtype='object')

# %% [markdown]
# ### Merging both the dataframes on outer join of State column

# %%
df_2c = pd.merge(df_2b, df_2a, how='outer', on= 'State')

# %%
df_2c.shape
# Out:
# (29, 6)

# %%
df_2c
# Out:
#                 State  Primary - 2014-2015.1  Upper Primary - 2014-2015  \
# 0      Andhra Pradesh                   6.72                       5.20
# 1   Arunachal Pradesh                  10.82                       6.71
# 2               Assam                  15.36                      10.51
# 3               Bihar                    NaN                       4.08
# 4         Chhatisgarh                   2.91                       5.85
# 5                 Goa                   0.73                       0.07
# 6             Gujarat                   0.89                       6.41
# 7             Haryana                   5.61                       5.81
# 8    Himachal Pradesh                   0.64                       0.87
# 9   Jammu and Kashmir                   6.79                       5.44
# 10          Jharkhand                   5.48                       8.99
# 11          Karnataka                   2.02                       3.85
# ...

# %%
df_2c.columns
# Out:
# Index(['State', 'Primary - 2014-2015.1', 'Upper Primary - 2014-2015',
#        'Secondary - 2014-2015', 'Senior Secondary - 2014-2015',
#        'Per Capita GSDP (Rs.)'],
#       dtype='object')

# %%
df_2d = df_2c[['State', 'Primary - 2014-2015.1', 'Per Capita GSDP (Rs.)']]
df_2e = df_2c[['State', 'Upper Primary - 2014-2015', 'Per Capita GSDP (Rs.)']]
df_2f = df_2c[['State', 'Secondary - 2014-2015', 'Per Capita GSDP (Rs.)']]

# %%
df_2d = df_2d.copy()
df_2d['Per Capita GSDP (Rs.)'] = pd.to_numeric(df_2d['Per Capita GSDP (Rs.)'])
df_2e = df_2e.copy()
df_2e['Per Capita GSDP (Rs.)'] = pd.to_numeric(df_2e['Per Capita GSDP (Rs.)'])
df_2f = df_2f.copy()
df_2f['Per Capita GSDP (Rs.)'] = pd.to_numeric(df_2f['Per Capita GSDP (Rs.)'])

# %% [markdown]
# ### Plotting the graph for GDP per capita with dropout rates in education (primary, upper primary and secondary) for the year 2014-2015 for each state

# %%
ax = df_2d.plot.scatter(title = 'GDP per capita with dropout rates in primary education for the year 2014-2015 for each state', x = 'Per Capita GSDP (Rs.)',y = 'Primary - 2014-2015.1', figsize=(16,8))
for i, txt in enumerate(df_2d.State):
    ax.annotate(txt, (df_2d['Per Capita GSDP (Rs.)'].iat[i],df_2d['Primary - 2014-2015.1'].iat[i]))
plt.show()

# %% [markdown]
# ## Goa has highest percapitaGDP with lowest dropoutrate for Primary education

# %%
ax = df_2e.plot.scatter(title = 'GDP per capita with dropout rates in upper primary education for the year 2014-2015 for each state', x = 'Per Capita GSDP (Rs.)',y = 'Upper Primary - 2014-2015', figsize=(16,8))
for i, txt in enumerate(df_2e.State):
    ax.annotate(txt, (df_2e['Per Capita GSDP (Rs.)'].iat[i],df_2e['Upper Primary - 2014-2015'].iat[i]))
plt.show()

# %% [markdown]
# ## Goa has highest percapitaGDP with lowest dropoutrate for Upper Primary education

# %%
ax = df_2f.plot.scatter(title = 'GDP per capita with dropout rates in secondary education for the year 2014-2015 for each state', x = 'Per Capita GSDP (Rs.)',y = 'Secondary - 2014-2015', figsize=(16,8))
for i, txt in enumerate(df_2f.State):
    ax.annotate(txt, (df_2f['Per Capita GSDP (Rs.)'].iat[i],df_2f['Secondary - 2014-2015'].iat[i]))
plt.show()

# %% [markdown]
# ## Bihar has lowest percapitaGDP with highest dropoutrate for Secondary education
